# %%
from deploy_contract import deploy_contract
deploy_contract()
# Out:
# Connected to Ganache, chain ID: 1337
# Available accounts: ['0xF86dd80Cb93832Ce7c6aF54355dc0b44c0112B14', '0xE221408760DA8f0e9e40bD0FA6Caf96649c24282', '0xb262473Cd66C9Cc22af67771e89Cc84D035AE582', '0x45C6Fd8f6626240a088E7D4A5E006730117CdbAA', '0xEd6c89c9168d0ce394841b09c01450C78E17AeFB', '0xc9dD0eF92B7218630F8Dc4F57AAB71C336276CAd', '0x53e7b294A7B3C0044618948a87fc61A7487e4C61', '0xD4198B4f918da7b99c3D3E73c55DA8D5dA3eE9FC', '0x3C618aD57cC0E153e1Ed8BF4F1633C10CcE15324', '0xB80aA5D2e53aF8Bb747A2b04cDBCD5CCF72007aD']
# Deploying contract...
# Waiting for the transaction to be mined...
# Contract deployed at address: 0xC87dA75e8a9CA1DB20e4c29F41246FF3393C8095
# Contract ABI and address saved to FederatedLearning.json
# ('0xC87dA75e8a9CA1DB20e4c29F41246FF3393C8095',
#  [{'inputs': [], 'stateMutability': 'nonpayable', 'type': 'constructor'},
#   {'anonymous': False,
#    'inputs': [{'indexed': True,
#      'internalType': 'uint256',
#      'name': 'roundId',
#      'type': 'uint256'},
# ...
